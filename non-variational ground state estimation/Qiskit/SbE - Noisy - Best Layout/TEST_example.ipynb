# %%
from qiskit_ibm_runtime import EstimatorV2 as Estimator
from qiskit_ibm_runtime import SamplerV2

import scipy.linalg as ln

from Ring import *

# %% [markdown]
# #### Retriving the fake Backend

# %%
from qiskit_ibm_runtime.fake_provider import FakeBrisbane

fake_backend = FakeBrisbane()

# %%
# Fixing the qubits to be used on the QPU 
layout = [37, 38, 39, 40 ,41, 53, 60, 59, 58, 57, 56, 52]

# Fanne uno per ognuno degli hardware in modo da utilizzare
# sempre il migliore possibile [TODO]

# Puoi anche investigare il plug_in "mapomatic" che vuole
# automatizzare questo step. [TODO]
# https://github.com/qiskit-community/mapomatic

# %% [markdown]
# #### Setting the number of sites of the ring ($\equiv$ number of qubit used)

# %%
# Ring sites
n_spin = 12

# Creation of the system Hamiltonian as SparsePauliOp
H = build_hamiltonian(n_spin)

# %% [markdown]
# #### Generating the annealing circuit

# %%
# Number of trotter step -- each trotter step is 15-CNOT deep
n_tstep = 4

# Creation of the annealing circuit
qc = trotterized_annealing(n_spin, n_tstep)

# %% [markdown]
# #### Transpiling the circuit to match the backend

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
pm = generate_preset_pass_manager(optimization_level=2, backend=fake_backend, initial_layout=layout)

# %%
# Transpile the circuit to an "Instruction Set Architecture" (ISA) circuit.
# Note: the transpiler automatically adds "ancilla" qubits to make the transpiled
# circuit match the size of the FakeSherbrooke backend.
isa_circ = pm.run(qc)

# circ.draw()

# %% [markdown]
# #### Execution of the energy estimation throught a Krylov-like Subspace Expansion.
# ##### Call $|\psi\rangle$ the state obtained by the execution of the annealing circuit, then we build the space $\{\mathrm{I}|\psi\rangle, H|\psi\rangle, H^2|\psi\rangle\}$ and solve the generilized eigenvalue problem $$ \mathcal{H}\nu = \varepsilon\mathcal{S}\nu $$ where $\mathcal{H}_{i,j} = \langle\psi|H^{i+j+1}|\psi\rangle$ and $\mathcal{S}_{i,j} = \langle\psi|H^{i+j}|\psi\rangle$

# %%
# Setting the maximum power of the Hamiltonian to use
max_pow = 2

# # Allocating the estiamtor to use for the Subpspace Expansion -- EXACT Estimator
# estimator = Estimator()

estimator = Estimator(mode=fake_backend)

# Retriving an energy estimation throught digitalized annealing + subspace expansion
estimate = energy_estimate_SbE(isa_circ, H, estimator, max_pow)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 10
#       7 estimator = Estimator(mode=fake_backend)
#       9 # Retriving an energy estimation throught digitalized annealing + subspace expansion
# ---> 10 estimate = energy_estimate_SbE(isa_circ, H, estimator, max_pow)
#
# File ~/Desktop/Università/Dottorato/Anno_III/Anelli/Qiskit/SbE - Noisy - Best Layout/Ring.py:74, in energy_estimate_SbE(circ, H, estimator, max_pow)
#      69 def energy_estimate_SbE(circ: QuantumCircuit,\
#      70                         H: HamOp,\
#      71                         estimator: Estimator,\
#      72                         max_pow: int) \
#      73                         -> float:
# ---> 74     return stima_energia_SbE(circ, H, estimator, max_pow)
#
# File ~/Desktop/Università/Dottorato/Anno_III/Anelli/Qiskit/SbE - Noisy - Best Layout/SbE.py:103, in stima_energia_SbE(circuit, Ham, estimator, n)
#      91 def stima_energia_SbE(circuit: QuantumCircuit,  \
#      92                         Ham: HamOp,             \
#      93                         estimator: Estimator,   \
#    (...)
#     101 #   Generiamo le matrici del problmea agli autovalori generalizzato che nasce
#     102 #   dalla Subspace Expansion (pesudocodice)
# --> 103     H, S = genera_matrici_SbE(circuit, Ham, estimator, n)
#     105 #   Risolviamo il problema agli autovalori generalizzato e ritorniamo
#     106 #   l'autovalore più piccolo in modulo
#     107     return ln.eigh(H, S, eigvals_only=True, subset_by_index=[0, 0])
#
# File ~/Desktop/Università/Dottorato/Anno_III/Anelli/Qiskit/SbE - Noisy - Best Layout/SbE.py:56, in genera_matrici_SbE(circuit, Ham, estimator, n)
#      53     isa_oss = oss.apply_layout(circuit.layout)
#      55 #   Stimiamo il valore di aspettazione di H
# ---> 56     va[1] = stima_aspettazione(circuit, isa_oss, estimator)
#      58 #   Cicliamo su tutte le potenze di cui calcolare i valori d'aspettazione
#      59     for i in range(2, pow_max + 1):
#      60
#      61 #       Calcoliamo la potenza attuale dell'Hamiltoniana suddivisa in gruppi di
#      62 #       operatori che commutano tra loro
#
# File ~/Desktop/Università/Dottorato/Anno_III/Anelli/Qiskit/SbE - Noisy - Best Layout/SbE.py:19, in stima_aspettazione(circuit, oss, estimator)
#      10 def stima_aspettazione(circuit: QuantumCircuit,     \
#      11                        oss: SparsePauliOp,          \
#      12                        estimator: Estimator)        \
#    (...)
#      16
#      17 #   Creazione ed esecuzione del job
#      18     job = estimator.run([(circuit, oss)])
# ---> 19     pub_result = job.result()[0]
#      21 #   Ritorniamo il valore d'aspettazione stimato
#      22     return pub_result.data.evs
#
# File ~/venv/qiskit_1.0.2/lib/python3.10/site-packages/qiskit/primitives/primitive_job.py:51, in PrimitiveJob.result(self)
#      49 def result(self) -> ResultT:
#      50     self._check_submitted()
# ---> 51     return self._future.result()
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:453, in Future.result(self, timeout)
#     450 elif self._state == FINISHED:
#     451     return self.__get_result()
# --> 453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     456     raise CancelledError()
#
# File /usr/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %% [markdown]
# #### Computing the exact ground state of the Hamiltonian

# %%
# Computing a numerical value of the system Hamiltonian [TBD]
H_num = evaluate_hamiltonian(H)

# Numerical diagonalization of the Hamiltonian [TBD]
e, V = ln.eigh(np.real(H_num), subset_by_index=[0, 0])

# Recuperiamo l'indice del groung state
id_gs = np.argmin(e)

# Recuperiamo il ground state e la relativa energia
gs     = V[:,id_gs]
energy = e[id_gs]

# %% [markdown]
# #### Comparison of the estimate from the Subspace Expansion with the exact (numerical) value of the ground state energy

# %%
err = abs(energy - estimate) / abs(energy)
print([energy, estimate, err])
