# %%
from qiskit_aer import AerSimulator
from qiskit_aer.noise import NoiseModel
from qiskit.primitives import BackendEstimator as Estimator

# from qiskit_ibm_runtime import EstimatorV2 as Estimator

import scipy.linalg as ln

from Ring import *

# %% [markdown]
# #### Retriving the fake Backend

# %%
from qiskit_ibm_runtime.fake_provider import FakeBrisbane

fake_backend = FakeBrisbane()

# %%
# Fixing the qubits to be used on the QPU 
layout = [37, 38, 39, 40 ,41, 53, 60, 59, 58, 57, 56, 52]

# Fanne uno per ognuno degli hardware in modo da utilizzare
# sempre il migliore possibile [TODO]

# Puoi anche investigare il plug_in "mapomatic" che vuole
# automatizzare questo step. [TODO]
# https://github.com/qiskit-community/mapomatic

# %% [markdown]
# #### Setting the number of sites of the ring ($\equiv$ number of qubit used)

# %%
# Ring sites
n_spin = 12

# Creation of the system Hamiltonian as SparsePauliOp
H = build_hamiltonian(n_spin)

# %% [markdown]
# #### Generating the annealing circuit

# %%
# Number of trotter step -- each trotter step is 15-CNOT deep
n_tstep = 4

# Creation of the annealing circuit
qc = trotterized_annealing(n_spin, n_tstep)

# qc.draw()

# %% [markdown]
# #### Transpiling the circuit to match the backend

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
pm = generate_preset_pass_manager(optimization_level=2, backend=fake_backend, initial_layout=layout)

# Transpile the circuit to an "Instruction Set Architecture" (ISA) circuit.
# Note: the transpiler automatically adds "ancilla" qubits to make the transpiled
# circuit match the size of the FakeSherbrooke backend.
isa_circ = pm.run(qc)

# qc.draw()
# isa_circ.draw()

# %% [markdown]
# #### Execution of the energy estimation throught a Krylov-like Subspace Expansion.
# ##### Call $|\psi\rangle$ the state obtained by the execution of the annealing circuit, then we build the space $\{\mathrm{I}|\psi\rangle, H|\psi\rangle, H^2|\psi\rangle\}$ and solve the generilized eigenvalue problem $$ \mathcal{H}\nu = \varepsilon\mathcal{S}\nu $$ where $\mathcal{H}_{i,j} = \langle\psi|H^{i+j+1}|\psi\rangle$ and $\mathcal{S}_{i,j} = \langle\psi|H^{i+j}|\psi\rangle$

# %%
# Setting the maximum power of the Hamiltonian to use
max_pow = 2

# Creazione del simulatore rumoroso
# Utilizziamo un noise model estratto da un backend fake (FakeVigo)
noise_model = NoiseModel.from_backend(fake_backend)
simulator = AerSimulator(noise_model=noise_model)

# # Allocating the estiamtor to use for the Subpspace Expansion -- EXACT Estimator
# estimator = Estimator()

# Da usare con AerSimulator
estimator = Estimator(simulator)

# estimator = Estimator(mode=fake_backend)

# %%
# Apriamo il file di output per la stampa dei valori di aspettazione calcolati
output = open("./Results/exp_values.txt", "w")

# Retriving an energy estimation throught digitalized annealing + subspace expansion
estimate = energy_estimate_SbE(qc, H, estimator, max_pow, layout, fake_backend, output)

# Chiudiamo il file di output per la stampa dei valori di aspettazione calcolati
output.close()
# Out:
# thread '<unnamed>' panicked at crates/accelerate/src/euler_one_qubit_decomposer.rs:1114:26:
# called `Result::unwrap()` on an `Err` value: TargetKeyError { message: "[PhysicalQubit(60)] not in Target" }
# note: run with `RUST_BACKTRACE=1` environment variable to display a backtrace
# thread '<unnamed>' panicked at crates/accelerate/src/euler_one_qubit_decomposer.rs:1114:26:
# called `Result::unwrap()` on an `Err` value: TargetKeyError { message: "[PhysicalQubit(60)] not in Target" }
# note: run with `RUST_BACKTRACE=1` environment variable to display a backtrace
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# pyo3_runtime.PanicException: called `Result::unwrap()` on an `Err` value: TargetKeyError { message: "[PhysicalQubit(60)] not in Target" }
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 211, in _sendback_result
#     result_queue.put(_ResultItem(work_id, result=result,
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 371, in put
#     obj = _ForkingPickler.dumps(obj)
#   File "/usr/lib/python3.10/multiprocessing/reduction.py", line 51, in dumps
#     cls(buf, protocol).dump(obj)
# _pickle.PicklingError: Can't pickle <class 'pyo3_runtime.PanicException'>: import of module 'pyo3_runtime' failed
# """
#
# The above exception was the direct cause of the following exception:
#
# PicklingError                             Traceback (most recent call last)
# Cell In[8], line 5
#       2 output = open("./Results/exp_values.txt", "w")
#       4 # Retriving an energy estimation throught digitalized annealing + subspace expansion
# ----> 5 estimate = energy_estimate_SbE(qc, H, estimator, max_pow, layout, fake_backend, output)
#       7 # Chiudiamo il file di output per la stampa dei valori di aspettazione calcolati
#       8 output.close()
#
# File ~/Desktop/Università/Dottorato/Anno_III/Anelli/Qiskit/SbE - Noisy - BL - ZNE [TBD]/Ring.py:77, in energy_estimate_SbE(circ, H, estimator, max_pow, layout, backend, out)
#      69 def energy_estimate_SbE(circ: QuantumCircuit,   \
#      70                         H: HamOp,               \
#      71                         estimator: Estimator,   \
#    (...)
#      75                         out)                    \
#      76                         -> float:
# ---> 77     return stima_energia_SbE(circ, H, estimator, max_pow, layout, backend, out)
#
# File ~/Desktop/Università/Dottorato/Anno_III/Anelli/Qiskit/SbE - Noisy - BL - ZNE [TBD]/SbE.py:115, in stima_energia_SbE(circuit, Ham, estimator, n, layout, backend, out)
#     100 def stima_energia_SbE(circuit: QuantumCircuit,  \
#     101                         Ham: HamOp,             \
#     102                         estimator: Estimator,   \
#    (...)
#     113 #   Generiamo le matrici del problmea agli autovalori generalizzato che nasce
#     114 #   dalla Subspace Expansion (pesudocodice)
# --> 115     H, S = genera_matrici_SbE(circuit, Ham, estimator, n, layout, backend, out)
#     117 #   Risolviamo il problema agli autovalori generalizzato e ritorniamo
#     118 #   l'autovalore più piccolo in modulo
#     119     return ln.eigh(H, S, eigvals_only=True, subset_by_index=[0, 0])
#
# File ~/Desktop/Università/Dottorato/Anno_III/Anelli/Qiskit/SbE - Noisy - BL - ZNE [TBD]/SbE.py:62, in genera_matrici_SbE(circuit, Ham, estimator, n, layout, backend, out)
#      58     fold_factors = [1, 1.5, 2, 2.5, 3, 4, 5]
#      60 #   DA RIPENSARE:: COME INCLUDERE LA ZNE
#      61 #   Stimiamo il valore di aspettazione di H
# ---> 62     va[1] = stima_aspettazione_ZNE(circuit, oss, estimator, fold_factors, layout, backend, out)
#      64 #   Cicliamo su tutte le potenze di cui calcolare i valori d'aspettazione
#      65     for i in range(2, pow_max + 1):
#      66
#      67 #       Calcoliamo la potenza attuale dell'Hamiltoniana suddivisa in gruppi di
#      68 #       operatori che commutano tra loro
#
# File ~/Desktop/Università/Dottorato/Anno_III/Anelli/Qiskit/SbE - Noisy - BL - ZNE [TBD]/ZNE.py:64, in stima_aspettazione_ZNE(circuit, oss, estimator, fold_factors, layout, backend, out)
#      62 #       Creazione ed esecuzione del job
#      63         job = estimator.run([(isa_folded_circuit, isa_oss)])
# ---> 64         pub_result = job.result()[0]
#      66 #       Salvataggio valore d'aspettazione
#      67         exp_values.append(pub_result.data.evs)
#
# File ~/venv/qiskit_1.3.2/lib/python3.10/site-packages/qiskit/primitives/primitive_job.py:51, in PrimitiveJob.result(self)
#      49 def result(self) -> ResultT:
#      50     self._check_submitted()
# ---> 51     return self._future.result()
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:458, in Future.result(self, timeout)
#     456     raise CancelledError()
#     457 elif self._state == FINISHED:
# --> 458     return self.__get_result()
#     459 else:
#     460     raise TimeoutError()
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File /usr/lib/python3.10/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/venv/qiskit_1.3.2/lib/python3.10/site-packages/qiskit/primitives/backend_estimator_v2.py:189, in BackendEstimatorV2._run(self, pubs)
#     186 results = [None] * len(pubs)
#     187 for shots, lst in pub_dict.items():
#     188     # run pubs with the same number of shots at once
# --> 189     pub_results = self._run_pubs([pubs[i] for i in lst], shots)
#     190     # reconstruct the result of pubs
#     191     for i, pub_result in zip(lst, pub_results):
#
# File ~/venv/qiskit_1.3.2/lib/python3.10/site-packages/qiskit/primitives/backend_estimator_v2.py:200, in BackendEstimatorV2._run_pubs(self, pubs, shots)
#     198 flat_circuits = []
#     199 for pub in pubs:
# --> 200     data = self._preprocess_pub(pub)
#     201     preprocessed_data.append(data)
#     202     flat_circuits.extend(data.circuits)
#
# File ~/venv/qiskit_1.3.2/lib/python3.10/site-packages/qiskit/primitives/backend_estimator_v2.py:246, in BackendEstimatorV2._preprocess_pub(self, pub)
#     243     param_index = bc_param_ind[index]
#     244     param_obs_map[param_index].update(bc_obs[index])
# --> 246 bound_circuits = self._bind_and_add_measurements(circuit, parameter_values, param_obs_map)
#     247 return _PreprocessedData(bound_circuits, bc_param_ind, bc_obs)
#
# File ~/venv/qiskit_1.3.2/lib/python3.10/site-packages/qiskit/primitives/backend_estimator_v2.py:311, in BackendEstimatorV2._bind_and_add_measurements(self, circuit, parameter_values, param_obs_map)
#     309     # sort pauli_strings so that the order is deterministic
#     310     meas_paulis = PauliList(sorted(pauli_strings))
# --> 311     new_circuits = self._create_measurement_circuits(
#     312         bound_circuit, meas_paulis, param_index
#     313     )
#     314     circuits.extend(new_circuits)
#     315 return circuits
#
# File ~/venv/qiskit_1.3.2/lib/python3.10/site-packages/qiskit/primitives/backend_estimator_v2.py:394, in BackendEstimatorV2._create_measurement_circuits(self, circuit, observable, param_index)
#     391         meas_circuits.append(meas_circuit)
#     393 # unroll basis gates
# --> 394 meas_circuits = self._passmanager.run(meas_circuits)
#     396 # combine measurement circuits
#     397 preprocessed_circuits = []
#
# File ~/venv/qiskit_1.3.2/lib/python3.10/site-packages/qiskit/transpiler/passmanager.py:464, in _replace_error.<locals>.wrapper(*meth_args, **meth_kwargs)
#     461 @wraps(meth)
#     462 def wrapper(*meth_args, **meth_kwargs):
#     463     try:
# --> 464         return meth(*meth_args, **meth_kwargs)
#     465     except PassManagerError as ex:
#     466         raise TranspilerError(ex.message) from ex
#
# File ~/venv/qiskit_1.3.2/lib/python3.10/site-packages/qiskit/transpiler/passmanager.py:226, in PassManager.run(self, circuits, output_name, callback, num_processes)
#     223 if callback is not None:
#     224     callback = _legacy_style_callback(callback)
# --> 226 return super().run(
#     227     in_programs=circuits,
#     228     callback=callback,
#     229     output_name=output_name,
#     230     num_processes=num_processes,
#     231 )
#
# File ~/venv/qiskit_1.3.2/lib/python3.10/site-packages/qiskit/passmanager/passmanager.py:246, in BasePassManager.run(***failed resolving arguments***)
#     240 del kwargs
#     242 # Pass manager may contain callable and we need to serialize through dill rather than pickle.
#     243 # See https://github.com/Qiskit/qiskit-terra/pull/3290
#     244 # Note that serialized object is deserialized as a different object.
#     245 # Thus, we can reuse the same manager without state collision, without building it per thread.
# --> 246 return parallel_map(
#     247     _run_workflow_in_new_process,
#     248     values=in_programs,
#     249     task_kwargs={"pass_manager_bin": dill.dumps(self)},
#     250     num_processes=num_processes,
#     251 )
#
# File ~/venv/qiskit_1.3.2/lib/python3.10/site-packages/qiskit/utils/parallel.py:182, in parallel_map(task, values, task_args, task_kwargs, num_processes)
#     180     # Otherwise just reset parallel flag and error
#     181     os.environ["QISKIT_IN_PARALLEL"] = "FALSE"
# --> 182     raise error
#     184 os.environ["QISKIT_IN_PARALLEL"] = "FALSE"
#     185 return results
#
# File ~/venv/qiskit_1.3.2/lib/python3.10/site-packages/qiskit/utils/parallel.py:174, in parallel_map(task, values, task_args, task_kwargs, num_processes)
#     171         param = ((task, value, task_args, task_kwargs) for value in values)
#     172         future = executor.map(_task_wrapper, param)
# --> 174     results = list(future)
#     176 except (KeyboardInterrupt, Exception) as error:
#     177     if isinstance(error, KeyboardInterrupt):
#
# File /usr/lib/python3.10/concurrent/futures/process.py:575, in _chain_from_iterable_of_lists(iterable)
#     569 def _chain_from_iterable_of_lists(iterable):
#     570     """
#     571     Specialized implementation of itertools.chain.from_iterable.
#     572     Each item in *iterable* should be a list.  This function is
#     573     careful not to keep references to yielded objects.
#     574     """
# --> 575     for element in iterable:
#     576         element.reverse()
#     577         while element:
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:621, in Executor.map.<locals>.result_iterator()
#     618 while fs:
#     619     # Careful not to keep a reference to the popped future
#     620     if timeout is None:
# --> 621         yield _result_or_cancel(fs.pop())
#     622     else:
#     623         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:319, in _result_or_cancel(***failed resolving arguments***)
#     317 try:
#     318     try:
# --> 319         return fut.result(timeout)
#     320     finally:
#     321         fut.cancel()
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# PicklingError: Can't pickle <class 'pyo3_runtime.PanicException'>: import of module 'pyo3_runtime' failed

# %% [markdown]
# #### Computing the exact ground state of the Hamiltonian

# %%
# Computing a numerical value of the system Hamiltonian [TBD]
H_num = evaluate_hamiltonian(H)

# Numerical diagonalization of the Hamiltonian [TBD]
e, V = ln.eigh(np.real(H_num), subset_by_index=[0, 0])

# Recuperiamo l'indice del groung state
id_gs = np.argmin(e)

# Recuperiamo il ground state e la relativa energia
gs     = V[:,id_gs]
energy = e[id_gs]

# %% [markdown]
# #### Comparison of the estimate from the Subspace Expansion with the exact (numerical) value of the ground state energy

# %%
err = abs(energy - estimate) / abs(energy)
print([energy, estimate, err])
