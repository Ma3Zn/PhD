# %%
from qiskit.quantum_info import *
from qiskit import *

import numpy as np

from HamOp import *

from math import *

# %%
pauli1 = "XXI"
pauli2 = "IXX"

lista_pauli = [pauli1, pauli2];
print(lista_pauli)
print([lista_pauli,lista_pauli])
# Out:
# ['XXI', 'IXX']
# [['XXI', 'IXX'], ['XXI', 'IXX']]

# %%
print(lista_pauli[0])
# Out:
# XXI

# %%
lista_pauli.append(pauli1)

# %%
print(lista_pauli + lista_pauli)
# Out:
# ['XXI', 'IXX', 'XXI', 'XXI', 'IXX', 'XXI']

# %%
p = SparsePauliOp(lista_pauli)

# %%
print(p)
# Out:
# SparsePauliOp(['XXI', 'IXX', 'XXI'],
#               coeffs=[1.+0.j, 1.+0.j, 1.+0.j])

# %%
p.num_qubits
# Out:
# 3

# %%
p.coeffs
# Out:
# array([1.+0.j, 1.+0.j, 1.+0.j])

# %%
pp = SparsePauliOp("I")

# %%
a = np.zeros(3) + 1/4
a
# Out:
# array([0.25, 0.25, 0.25])

# %%
a = a + 1/4

# %%
np.concatenate([a,a,a])
# Out:
# array([0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5])

# %%
h = crea_hamiltonianaOp(4, True)

# %%
h.tot.argsort()
# Out:
# array([ 1,  5,  9,  2,  6, 10,  3,  0,  7,  4, 11,  8])

# %%
h.tot[h.tot.argsort()]
# Out:
# SparsePauliOp(['IIXX', 'IIYY', 'IIZZ', 'IXXI', 'IYYI', 'IZZI', 'XIIX', 'XXII', 'YIIY', 'YYII', 'ZIIZ', 'ZZII'],
#               coeffs=[0.25+0.j, 0.25+0.j, 0.25+0.j, 0.25+0.j, 0.25+0.j, 0.25+0.j, 0.25+0.j,
#  0.25+0.j, 0.25+0.j, 0.25+0.j, 0.25+0.j, 0.25+0.j])

# %%
a = h.tot.power(2).group_commuting()

# %%
len(a)
# Out:
# 6

# %%
a @ h.tot
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 a @ h.tot
#
# TypeError: unsupported operand type(s) for @: 'list' and 'SparsePauliOp'
